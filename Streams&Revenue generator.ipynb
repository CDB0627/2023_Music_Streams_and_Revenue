# %%
import pandas as pd
import numpy as np

# Define the list of songs with artist names, music categories, and genres
songs = [
   ("Shape of You", "Ed Sheeran", "Pop"),
    ("Uptown Funk", "Mark Ronson ft. Bruno Mars", "Funk"),
    ("Old Town Road", "Lil Nas X ft. Billy Ray Cyrus", "Country"),
    ("Blinding Lights", "The Weeknd", "R&B"),
    ("Someone Like You", "Adele", "Pop"),
    ("Thriller", "Michael Jackson", "Pop"),
    ("Billie Jean", "Michael Jackson", "Pop"),
    ("Smooth", "Santana", "Rock"),
    ("Crazy in Love", "Beyonce", "R&B"),
    ("Baby One More Time", "Britney Spears", "Pop"),
    ("I Will Always Love You", "Whitney Houston", "R&B"),
    ("I Want to Hold Your Hand", "The Beatles", "Rock"),
    ("Imagine", "John Lennon", "Pop"),
    ("Great Man", "Kevin Gates", "Hip Hop"),
    ("Lonely Child", "Youngboy Never Broke Again", "Hip Hop"),
    ("Born to Run", "Bruce Springsteen", "Rock"),
    ("Stairway to Heaven", "Led Zeppelin", "Rock"),
    ("Eye of the Tiger", "Survivor", "Rock"),
    ("Livin' on a Prayer", "Bon Jovi", "Rock"),
    ("The Box", "Roddy Ricch", "Hip Hop"),
    ("Watermelon Sugar", "Harry Styles", "Pop"),
    ("Sicko Mode", "Travis Scott", "Hip Hop"),
    ("Memories", "Maroon 5", "Pop"),
    ("Rockstar", "Post Malone ft. 21 Savage", "Hip Hop"),
    ("Sunflower", "Post Malone ft. Swae Lee", "Hip Hop"),
    ("Happier", "Marshmello ft. Bastille", "Electronic"),
    ("Savage Love", "Jawsh 685 ft. Jason Derulo", "Pop"),
    ("Circles", "Post Malone", "Pop"),
    ("The Box", "Roddy Ricch", "Hip Hop"),
    ("Rain On Me", "Lady Gaga ft. Ariana Grande", "Pop"),
    ("Blinding Lights", "The Weeknd", "R&B"),
    ("Rockstar", "DaBaby ft. Roddy Ricch", "Hip Hop"),
    ("The Bones", "Maren Morris", "Country"),
    # Add more songs from various genres as needed
]

# Define the revenue rates for each platform and each artist
revenue_rates = {
    "Spotify": {"Ed Sheeran": np.random.uniform(0.003, 0.007)},
    "Apple Music": {"Ed Sheeran": np.random.uniform(0.003, 0.007)},
    "YouTube Music": {"Ed Sheeran": np.random.uniform(0.002, 0.006)},
    "Tidal": {"Ed Sheeran": np.random.uniform(0.004, 0.008)},
    # Add more artists and their revenue rates as needed
}

# Define the list of demographics of listeners
demographics = ["18-24", "25-34", "35-44", "45-54", "55+"]

# Define the list of states in the US
us_states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", 
    "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", 
    "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", 
    "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", 
    "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
    "West Virginia", "Wisconsin", "Wyoming"
]

# Define months in the year 
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# Generate synthetic data for each song
data = []

for (song_title, artist, category) in songs:
    for platform, artist_rates in revenue_rates.items():
        revenue_rate = artist_rates.get(artist, np.random.uniform(0.003, 0.007))
        for demographic in demographics:
            for state in us_states:
                for month in months:
                    # Generate random stream count
                    stream_count = np.random.randint(1, 100000000)
                    # Calculate revenue per stream based on the revenue rate for the platform
                    revenue_per_stream = revenue_rate
                    revenue = stream_count * revenue_per_stream
                
                    # Append data to the list
                    data.append([song_title, artist, category, platform, demographic, state, month, stream_count, revenue_per_stream, revenue])

# Create DataFrame
columns = ["Song Title", "Artist", "Category", "Platform", "Demographic", "State", "Month", "Stream Count", "Revenue Per Stream", "Revenue"]
df = pd.DataFrame(data, columns=columns)

# Save DataFrame to Excel
df.to_excel("top_songs_2023_dataset(raw).xlsx", index=False)
